# %% [markdown]
# ## Working with Dates and Times in Python

# %%
## importing the date function within the datetime package

from datetime import date

# %%
### to create a today object

today = date(2026, 6,20)

# %%
today
# Out:
# datetime.date(2026, 6, 20)

# %%
## if i want to know the week of day of the today
## python index starting from 0, with 0 being Monday, then 5 in this case is Saturday
print(today.weekday())
# Out:
# 5

# %%
### using attributes like .year, .month, .day to get relevant date information
print(today.year)
print(today.month)
print(today.day)
# Out:
# 2026
# 6
# 20

# %%
# Import date
from datetime import date

# Create a date object for May 9th, 2007
start = date(2007, 5, 9)

# Create a date object for December 13th, 2007
end = date(2007, 12, 13)

# Subtract the two dates and print the number of days
print((end - start).days)
# Out:
# 218

# %%
# Import date
from datetime import date

# Create a date object
andrew = date(1992, 8, 26)

# Print the date in the format 'YYYY-MM'
print(andrew.strftime("%Y-%m"))


# Create a date object
andrew = date(1992, 8, 26)

# Print the date in the format 'MONTH (YYYY)'
print(andrew.strftime("%B (%Y)"))

# Create a date object
andrew = date(1992, 8, 26)

# Print the date in the format 'YYYY-DDD'
print(andrew.strftime("%Y-%j"))
# Out:
# 1992-08
# August (1992)
# 1992-239

# %%
### import datetime from datetime

from datetime import datetime

date_ = datetime(2026, 6, 20, 12, 30, 45)

# %%
date_.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2026-06-20 12:30:45'

# %%
date_.strftime("%Y-%m-%d")
# Out:
# '2026-06-20'

# %%
result = date_.strftime("%Y-%m-%d")

# %%
print(date_.isoformat())
# Out:
# 2026-06-20T12:30:45

# %%
## parse the datetime using strptime()
date_.strptime("2026-06-20 12:30:45", "%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2026, 6, 20, 12, 30, 45)

# %%
type(result)
# Out:
# str

# %% [markdown]
#  timestamp
#
#  .fromtimpstamp() method to convert a timestamp into a datetime object

# %% [markdown]
# total_seconds() method to get the total number of seconds in a timedelta object

# %%
from datetime import datetime, timedelta, timezone

# %%
pt = timezone(timedelta(hours = -8))

# %%
pt_time = datetime(2026, 6, 20, 12, 30, 45, tzinfo = pt)

# %%
print(pt_time)
# Out:
# 2026-06-20 12:30:45-08:00

# %%
print(pt_time.replace(tzinfo = timezone.utc))
# Out:
# 2026-06-20 12:30:45+00:00

# %%
# Loop over the trips
for trip in onebike_datetimes[:10]:
  # Pull out the start
  dt = trip['start']
  # Move dt to be in UTC
  dt = dt.astimezone(timezone.utc)
  
  # Print the start time in UTC
  print('Original:', trip['start'], '| UTC:', dt.isoformat())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-506b70388633> in <module>
#       1 # Loop over the trips
# ----> 2 for trip in onebike_datetimes[:10]:
#       3   # Pull out the start
#       4   dt = trip['start']
#       5   # Move dt to be in UTC
#
# NameError: name 'onebike_datetimes' is not defined

# %% [markdown]
# dt is Pandas' datetime accessor. It lets you use datetime-specific methods and properties on a Series of datetime values.

# %% [markdown]
# rides['Start date'] = rides['Start date'].dt.tz_localize('America/New_York',
#                                 						 ambiguous='NaT')
