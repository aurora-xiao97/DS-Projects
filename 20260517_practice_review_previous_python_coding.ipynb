# %% [markdown]
# ### Incorrect Questions

# %% [markdown]
# What does 'hello'.find('l') return?
#
# .find(sub) returns the index of the first occurrence, or -1 if not found. 'l' first appears at index 2.

# %% [markdown]
# What does d.items() return?
#
# .items() returns a view of all key-value pairs as tuples.

# %% [markdown]
# Difference between list.pop(index is optional) vs dic.pop('age')

# %% [markdown]
# These two the list pop method delte the value and you could provide an index value to give the deletion process more guidance.
# However, for the dic.pop('age') this age value search and delete the pair and return the value is necessary

# %% [markdown]
# What does a for loop do?
#
# for var in seq: expression — for each variable in the sequence, execute the expression.
