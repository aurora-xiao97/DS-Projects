# %% [markdown]
# ### Review Previous Questions

# %% [markdown]
# #### 1.Data Types & Basics

# %% [markdown]
# Q1: How do you check the data type of a variable?

# %%
num = [1,2,3,4,5]

# %%
print(type(num))
# Out:
# <class 'list'>

# %% [markdown]
# Q2: What are the 4 core Python data types you listed?

# %%
int, float, str, bool, list, tuple, set, dict

# %% [markdown]
# #### 2. Lists - Creation & Access

# %% [markdown]
# Q3: How do you create a list? "Liz", 1.73, "emma", 1.68, "mom", 1.71, "dad", 1.89

# %%
name_height = ["Liz", 1.73, "emma", 1.68, "mom", 1.71, "dad", 1.89]

# %%
print(type(name_height))
# Out:
# <class 'list'>

# %% [markdown]
# Q4: How do you access the first element?

# %%
name_height[0]
# Out:
# 'Liz'

# %% [markdown]
# Q5: How do you access the last element?

# %%
name_height[-1]
# Out:
# 1.89

# %% [markdown]
# Q6: How do you slice a list from index i to j?

# %%
## slice second to third
name_height[1:3]
# Out:
# [1.73, 'emma']

# %% [markdown]
# Q7: Is slicing inclusive or exclusive?

# %%
left inclusive, right exclusive

# %% [markdown]
# #### 3. Lists - Modification

# %% [markdown]
# Q8: How do you add an item to the end of a list? two ways, add items at the end

# %%
 name_height+=["Ting"]

# %%
name_height.append(1.62)

# %%
name_height
# Out:
# ['Liz', 1.73, 'emma', 1.68, 'mom', 1.71, 'dad', 1.89, 'Ting', 1.62]

# %% [markdown]
# Q9: How do you insert an item at a specific index?

# %%
name_height.insert(2, "Tim")

# %%
name_height
# Out:
# ['Liz', 1.73, 'Tim', 'emma', 1.68, 'mom', 1.71, 'dad', 1.89, 'Ting', 1.62]

# %%
name_height.insert(3,1.70)

# %%
name_height
# Out:
# ['Liz', 1.73, 'Tim', 1.7, 'emma', 1.68, 'mom', 1.71, 'dad', 1.89, 'Ting', 1.62]

# %% [markdown]
# Q10: How do you combine two lists?

# %%
additonal_name_height = ["Aurora", 1.75]

# %%
name_height + additonal_name_height
# Out:
# ['Liz',
#  1.73,
#  'Tim',
#  1.7,
#  'emma',
#  1.68,
#  'mom',
#  1.71,
#  'dad',
#  1.89,
#  'Ting',
#  1.62,
#  'Aurora',
#  1.75]

# %% [markdown]
# #### 4.Lists - Removing Elements

# %% [markdown]
# Q11: How do you remove an item by value?

# %%
name_height.remove("Tim")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-cdbd1399b737> in <module>
# ----> 1 name_height.remove("Tim")
#
# ValueError: list.remove(x): x not in list

# %%
name_height
# Out:
# ['Liz', 1.73, 1.7, 'emma', 1.68, 'mom', 1.71, 'dad', 1.89, 'Ting', 1.62]

# %% [markdown]
# Q12: What does remove() return?

# %% [markdown]
# it does not return anything

# %% [markdown]
# Q13: How do you remove and return the last element?

# %%
name_height.pop()
# Out:
# 1.62

# %% [markdown]
# Q14: How do you remove an item by index?

# %%
del name_height[2]

# %%
name_height
# Out:
# ['Liz', 1.73, 'emma', 1.68, 'mom', 1.71, 'dad', 1.89, 'Ting']

# %% [markdown]
# what does del fam[2] do?

# %% [markdown]
# it removes the value based on the index value provided but also no value return

# %% [markdown]
# Q15: How do you remove and return an element at index i?

# %%
name_height.pop(3)
# Out:
# 1.68

# %% [markdown]
# Q16: What's the difference between remove() and pop()?

# %% [markdown]
# remove by value and no return value, pop() return value index is optional
#
# remove by actual value but pop with index number

# %% [markdown]
# #### Lists - Copying (very important)

# %% [markdown]
# Q17: What happens with y = x?

# %% [markdown]
# y and x bond together if change of x will impact the value in y as well

# %% [markdown]
# Q18: How do you create a copy using slicing?

# %%
copy_name_height = name_height[:]

# %%
copy_name_height
# Out:
# ['Liz', 1.73, 'emma', 'mom', 1.71, 'dad', 1.89, 'Ting']

# %% [markdown]
# Q19: How do you create a copy using a method?

# %% [markdown]
# y= x.copy()

# %% [markdown]
# Q20: How do you create a copy using constructor?

# %% [markdown]
# y = list(x)

# %% [markdown]
# Q21: Additional List question
#
# Which of these is a valid Python list?
# - (1,2,3)
# - {'a':1}
# - [1, 'hello', 1.73]
# - {1,2,3}

# %% [markdown]
# Q22: Given fam = ['Liz', 1.73, 'emma', 1.68, 'mom', 1.71], what does fam[2] return?

# %% [markdown]
# Q23: List Indexing
# What does fam.index('mom') return if 'mom' is at position 4?

# %% [markdown]
# Q24: What does fam.count(1.73) do?

# %% [markdown]
# ### Lists - Sorting

# %% [markdown]
# Q25: How do you sort a list in-place?

# %%
height_only = [1.5, 1.8, 1.62, 1.73, 1.68, 1.71, 1.89, 1.70, 1.75]

# %%
height_only.sort()

# %%
height_only
# Out:
# [1.5, 1.62, 1.68, 1.7, 1.71, 1.73, 1.75, 1.8, 1.89]

# %% [markdown]
# Q26: How do you reverse the list in-place?

# %%
height_only.reverse()

# %%
height_only
# Out:
# [1.89, 1.8, 1.75, 1.73, 1.71, 1.7, 1.68, 1.62, 1.5]

# %% [markdown]
# Q27: How do you remove All items from a list?

# %% [markdown]
# Q28: How do you remove  the first occurrence of value 'a' from a list?

# %% [markdown]
# ### Strings

# %% [markdown]
# Q29: What does 'a,b,c'.split(',') return?

# %% [markdown]
# Q30: What does ','.join(['a','b']) return?

# %% [markdown]
# 'a,b'

# %% [markdown]
# Q31: What does 'hello'.find('l') return?

# %% [markdown]
# Q32: If you're filtering a list of filenames to find CSVs from a specific project, starting with a name of 'JD27' what function would you use to check if the filename starts with 'JD27'? and if the file endswith '.csv'

# %% [markdown]
# Q33: Summary the difference between .remove(), .pop(), and del?

# %% [markdown]
# Q34: How do you import NumPy with the standard alias?

# %% [markdown]
# Q35: What does np_height[:, 1:3] select?

# %% [markdown]
# Q36: What is the result of np.logical_not(np.array([0.0, 0.1, -2.5]))?

# %% [markdown]
# Q37: How do you generate pseudo-random numbers in NumPy?

# %% [markdown]
# np.random.rand() or np.random.random() generates pseudo-random numbers. Use np.random.seed(123) for reproducibility.

# %% [markdown]
# Q38: What does np.random.randint(0, 2) generate?

# %% [markdown]
# Q39: How to check if a key exist in a dictionary?

# %% [markdown]
# Use 'key' in dictionary — returns True or False.

# %% [markdown]
# Q40: What does d.get('name', 'unknown') return?

# %% [markdown]
# .get(key, default) returns the value for the key, or the default value if the key is not found.

# %% [markdown]
# Q41: What does d.keys() return?

# %% [markdown]
# Q42: What does d.items() return?

# %% [markdown]
# Q43: What does d.pop('age') do?

# %% [markdown]
# Q44: How do you update multiple keys at once in a dictionary?

# %% [markdown]
# d.update({...}) updates the dictionary with another dictionary or key-value pairs — useful for bulk updates.

# %% [markdown]
# Q45: How do you select a single column from a DataFrame as a Series?

# %% [markdown]
# brics['country'] returns a Pandas Series. brics[['country']] returns a DataFrame.

# %% [markdown]
# Q46: What does df.drop_duplicates() do?

# %% [markdown]
# Q47: What does df.sort_values('col', ascending=False) do?

# %% [markdown]
# Q48: How do you subset rows where height is over 50?

# %% [markdown]
# Q49: What does df.agg({'A':'sum','B':'mean'}) do?

# %% [markdown]
# Q50: What does df.cumsum() do?

# %% [markdown]
# Q51: In a while loop, when does the code block execute?

# %% [markdown]
# Q52: What does a for loop do?

# %% [markdown]
# Q53: What is enumerate(seq) used for?

# %% [markdown]
# enumerate(iterable, start=0) loops over a sequence keeping track of the index. Returns (index, value) pairs.

# %% [markdown]
# Q54: How do you loop over a dictionary's key-value pairs?

# %% [markdown]
# Q55: What is the operator for 'strictly less than'?

# %% [markdown]
# Q56: How do you import matplotlib for plotting?

# %% [markdown]
# Q57: Which function creates a basic line graph?

# %% [markdown]
# plt.plot(x, y) creates a line graph. Follow with plt.show() to display.

# %% [markdown]
# Q58: Which function creates a scatter plot?

# %% [markdown]
# Q59: How do you create a histogram with 3 bins?

# %% [markdown]
# Q60: Which function adds a label to the x-axis?
