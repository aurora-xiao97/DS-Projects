# %% [markdown]
# ## Introduction to Importing Data in Python

# %%
with open('/Users/auroraxiao/Desktop/Data Science Project/DS-Projects/Data Set/Ting_file.txt', 'r') as file:
    print(file.read())
# Out:
# Hello World! Hello Ting!

# %% [markdown]
# with open('file name', 'r' or 'w') as file:
#
#     print(file.read())

# %% [markdown]
# ### What if I only want to print  only the first few lines
# using .readline()

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5, 6])

np.reshape(a, (2, 3))
# array([[1, 2, 3],
#        [4, 5, 6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
